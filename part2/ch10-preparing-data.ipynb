# %%
from utils.dsets import getCandidateInfo, getCt, LunaDataset
import os

# %%
candidate_info_list = getCandidateInfo()
positive_info_list = [x for x in candidate_info_list if x[0]]
diameter_list = [x[1] for x in positive_info_list]

# %%
len(diameter_list)
# Out:
# 277

# %%
for i in range(0, len(diameter_list),10):
    print(f"{i} {diameter_list[i]}mm")
# Out:
# 0 32.27003025mm
# 10 20.11629595mm
# 20 17.39699158mm
# 30 14.62904955mm
# 40 12.99686424mm
# 50 11.48732767mm
# 60 10.46585391mm
# 70 9.404294354mm
# 80 8.501262355mm
# 90 8.220380612mm
# 100 7.72427841mm
# 110 7.165672419mm
# 120 6.875805854mm
# 130 6.49900752mm
# 140 6.246461343mm
# 150 5.970538617mm
# 160 5.556944532mm
# 170 5.127950372mm
# 180 4.915612527mm
# 190 4.506689862mm
# 200 3.951407423mm
# 210 0.0mm
# 220 0.0mm
# 230 0.0mm
# 240 0.0mm
# 250 0.0mm
# 260 0.0mm
# 270 0.0mm

# %%
from utils.viz import findPositiveSamples, showCandidate
# %matplotlib inline

# %%
series_uid = positive_info_list[200][2]
series_uid
# Out:
# '1.3.6.1.4.1.14519.5.2.1.6279.6001.336894364358709782463716339027'

# %%
showCandidate(series_uid)
# Out:
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.336894364358709782463716339027 0 False [0]
